# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import warnings

warnings.filterwarnings('ignore')
tf.random.set_seed(42)
np.random.seed(42)

print("="*50)
print("🚀 SYSTEM READY: LSTM PREDICTION MODEL")
print("="*50)
print(f"TensorFlow Version: {tf.__version__}")
# Out:
# ==================================================
# 🚀 SYSTEM READY: LSTM PREDICTION MODEL
# ==================================================
# TensorFlow Version: 2.18.0

# %%
# Konfigurasi Data
TICKER = 'NVDA'       # Ganti dengan saham pilihan Anda
START_DATE = '2018-01-01'
END_DATE = '2024-12-31'

print(f"📥 Mengunduh data {TICKER}...")
df = yf.download(TICKER, start=START_DATE, end=END_DATE, progress=False)

# Handling MultiIndex kolom (jika ada update yfinance terbaru)
if isinstance(df.columns, pd.MultiIndex):
    df.columns = df.columns.get_level_values(0)

print(f"✅ Data berhasil diunduh. Dimensi: {df.shape}")
df.head()
# Out:
# 📥 Mengunduh data NVDA...
# ✅ Data berhasil diunduh. Dimensi: (1760, 5)
# Price          Close      High       Low      Open     Volume
# Date
# 2018-01-02  4.928533  4.932241  4.808626  4.840271  355616000
# 2018-01-03  5.252898  5.283307  5.037313  5.045966  914704000
# 2018-01-04  5.280588  5.390853  5.258337  5.334237  583268000
# 2018-01-05  5.325336  5.362667  5.218532  5.295421  580124000
# 2018-01-08  5.488510  5.562679  5.403957  5.448953  881216000

# %%
# ==========================================
# CELL 3 (UPDATE): FEATURE ENGINEERING (CALCULATION)
# ==========================================
def add_technical_indicators(df):
    df = df.copy()
    
    # 1. Basic Returns
    df['Log_Return'] = np.log(df['Close'] / df['Close'].shift(1))
    
    # 2. RSI (Relative Strength Index)
    delta = df['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    df['RSI'] = 100 - (100 / (1 + rs))
    
    # 3. MACD Complex
    exp1 = df['Close'].ewm(span=12, adjust=False).mean()
    exp2 = df['Close'].ewm(span=26, adjust=False).mean()
    df['MACD'] = exp1 - exp2
    df['MACD_Signal'] = df['MACD'].ewm(span=9, adjust=False).mean()
    df['MACD_Hist'] = df['MACD'] - df['MACD_Signal'] 
    
    # 4. Bollinger Bands
    df['BB_MA'] = df['Close'].rolling(window=20).mean()
    bb_std = df['Close'].rolling(window=20).std()
    df['BB_Upper'] = df['BB_MA'] + (bb_std * 2)
    df['BB_Lower'] = df['BB_MA'] - (bb_std * 2)
    df['BB_Position'] = (df['Close'] - df['BB_Lower']) / (df['BB_Upper'] - df['BB_Lower'])
    
    # 5. Volume & Volatility
    df['Volume_Log'] = np.log1p(df['Volume'])
    df['Volume_MA_Ratio'] = df['Volume'] / df['Volume'].rolling(window=20).mean()
    df['Volatility'] = df['Log_Return'].rolling(window=20).std()
    
    # 6. Momentum Indicators
    df['Momentum_10'] = df['Close'].pct_change(periods=10)
    df['MA_Ratio_5_20'] = df['Close'].rolling(5).mean() / df['Close'].rolling(20).mean()
    df['MA_Ratio_20_50'] = df['Close'].rolling(20).mean() / df['Close'].rolling(50).mean()
    
    # 7. ATR (Volatility)
    df['High_Low'] = df['High'] - df['Low']
    df['ATR'] = df['High_Low'].rolling(window=14).mean()
    
    # 8. Lagged Returns
    for lag in [1, 2, 3, 5]:
        df[f'Return_Lag_{lag}'] = df['Log_Return'].shift(lag)
        
    return df.dropna()

df_processed = add_technical_indicators(df)
print(f"✅ Kalkulasi Semua Indikator Selesai. Total baris data: {len(df_processed)}")
# Out:
# ✅ Kalkulasi Semua Indikator Selesai. Total baris data: 1711

# %%
# ==========================================
# CELL 4 (UPDATE): SELEKSI FITUR (OPTIMIZED TOP 5)
# ==========================================
# Target Prediction (Log Return Besok)
df_processed['Target'] = df_processed['Log_Return'].shift(-1)
df_processed = df_processed.dropna()

# ---------------------------------------------------------
# STRATEGI: FEATURE SELECTION
# Kita membuang fitur redundant (Noise) dan hanya menyisakan
# 5 fitur dengan Importance tertinggi dari eksperimen sebelumnya.
# ---------------------------------------------------------
feature_cols = [
    'Log_Return',    # Data Utama (Harga)
    'Volume_Log',    # Validasi Tren (Likuiditas)
    'ATR',           # Volatilitas (Range Harga) - TERPENTING
    'RSI',           # Momentum (Jenuh Beli/Jual)
    'Volatility'     # Risiko Pasar
]

# Note: 
# - MACD, Bollinger Bands, dan MA Ratios dibuang karena terbukti noise.
# - Lag Returns dibuang karena LSTM sudah memiliki memori internal.

X = df_processed[feature_cols].values
y = df_processed[['Target']].values

print(f"📌 Fitur Terpilih (Optimized - {len(feature_cols)} Fitur): {feature_cols}")
print("✅ Data Siap untuk Training Model Teroptimasi")
# Out:
# 📌 Fitur Terpilih (Optimized - 5 Fitur): ['Log_Return', 'Volume_Log', 'ATR', 'RSI', 'Volatility']
# ✅ Data Siap untuk Training Model Teroptimasi

# %%
# Split Data (80% Train, 20% Test)
split_idx = int(len(X) * 0.8)

X_train_raw = X[:split_idx]
y_train_raw = y[:split_idx]
X_test_raw = X[split_idx:]
y_test_raw = y[split_idx:]

# Scaling (Fit hanya di Train, Transform di Test)
scaler_X = StandardScaler()
scaler_y = MinMaxScaler(feature_range=(-1, 1))

X_train_scaled = scaler_X.fit_transform(X_train_raw)
y_train_scaled = scaler_y.fit_transform(y_train_raw)

X_test_scaled = scaler_X.transform(X_test_raw)
y_test_scaled = scaler_y.transform(y_test_raw)

print("✅ Splitting & Scaling selesai (Aman dari Data Leakage)")
print(f"   Train size: {len(X_train_scaled)} | Test size: {len(X_test_scaled)}")
# Out:
# ✅ Splitting & Scaling selesai (Aman dari Data Leakage)
#    Train size: 1368 | Test size: 342

# %%
def create_sequences(X, y, time_steps=60):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:(i + time_steps)])
        ys.append(y[i + time_steps])
    return np.array(Xs), np.array(ys)

TIME_STEPS = 60

X_train, y_train = create_sequences(X_train_scaled, y_train_scaled, TIME_STEPS)
X_test, y_test = create_sequences(X_test_scaled, y_test_scaled, TIME_STEPS)

print(f"📦 Sequence terbentuk (Window: {TIME_STEPS} hari)")
print(f"   Input Shape: {X_train.shape} (Sampel, TimeSteps, Fitur)")
# Out:
# 📦 Sequence terbentuk (Window: 60 hari)
#    Input Shape: (1308, 60, 5) (Sampel, TimeSteps, Fitur)

# %%
# ==========================================
# CELL 7 (UPDATE): ARSITEKTUR BIDIRECTIONAL LSTM
# ==========================================
from tensorflow.keras.layers import Bidirectional

model = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    
    # Layer 1: Bidirectional LSTM (Baca pola maju & mundur)
    Bidirectional(LSTM(64, return_sequences=True, kernel_regularizer=l2(0.001))),
    BatchNormalization(),
    Dropout(0.3),
    
    # Layer 2: LSTM Biasa
    LSTM(64, return_sequences=False, kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.3),
    
    # Output Layer
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
model.summary()
print("🚀 Model Upgrade: Bidirectional LSTM Siap!")
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_3 (Bidirectional) │ (None, 60, 128)        │        35,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 60, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 60, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 88,129 (344.25 KB)
#  Trainable params: 87,745 (342.75 KB)
#  Non-trainable params: 384 (1.50 KB)
# 🚀 Model Upgrade: Bidirectional LSTM Siap!

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 1.9104 - mae: 1.0123 - val_loss: 0.3549 - val_mae: 0.3186 - learning_rate: 0.0010
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.8852 - mae: 0.6453 - val_loss: 0.3063 - val_mae: 0.2415 - learning_rate: 0.0010
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6945 - mae: 0.5364 - val_loss: 0.2954 - val_mae: 0.2220 - learning_rate: 0.0010
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.5187 - mae: 0.4308 - val_loss: 0.2735 - val_mae: 0.1801 - learning_rate: 0.0010
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4802 - mae: 0.4017 - val_loss: 0.3115 - val_mae: 0.2652 - learning_rate: 0.0010
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.4539 - mae: 0.3780 - val_loss: 0.3074 - val_mae: 0.2649 - learning_rate: 0.0010
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.4021 - mae: 0.3424 - val_loss: 0.2647 - val_mae: 0.1800 - learning_rate: 0.0010
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.3845 - mae: 0.3278 - val_loss: 0.2617 - val_mae: 0.1845 - learning_rate: 0.0010
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.3644 - mae: 0.3012 - val_loss: 0.2700 - val_mae: 0.2095 - learning_rate: 0.0010
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.3274 - mae: 0.2755 - val_loss: 0.2530 - val_mae: 0.1804 - learning_rate: 0.0010
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.3239 - mae: 0.2720 - val_loss: 0.2424 - val_mae: 0.1670 - learning_rate: 0.0010
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.3066 - mae: 0.2545 - val_loss: 0.2716 - val_mae: 0.2350 - learning_rate: 0.0010
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2944 - mae: 0.2429 - val_loss: 0.2438 - val_mae: 0.1836 - learning_rate: 0.0010
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.2697 - mae: 0.2216 - val_loss: 0.2415 - val_mae: 0.1863 - learning_rate: 0.0010
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2698 - mae: 0.2227 - val_loss: 0.2395 - val_mae: 0.1907 - learning_rate: 0.0010
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.2524 - mae: 0.2040 - val_loss: 0.2320 - val_mae: 0.1849 - learning_rate: 0.0010
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.2373 - mae: 0.1912 - val_loss: 0.2132 - val_mae: 0.1526 - learning_rate: 0.0010
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2325 - mae: 0.1860 - val_loss: 0.2046 - val_mae: 0.1429 - learning_rate: 0.0010
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.2279 - mae: 0.1834 - val_loss: 0.1987 - val_mae: 0.1380 - learning_rate: 0.0010
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2185 - mae: 0.1812 - val_loss: 0.1976 - val_mae: 0.1446 - learning_rate: 0.0010
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.2124 - mae: 0.1687 - val_loss: 0.1913 - val_mae: 0.1393 - learning_rate: 0.0010
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.2068 - mae: 0.1695 - val_loss: 0.1876 - val_mae: 0.1393 - learning_rate: 0.0010
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.1962 - mae: 0.1555 - val_loss: 0.1828 - val_mae: 0.1369 - learning_rate: 0.0010
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1969 - mae: 0.1631 - val_loss: 0.1782 - val_mae: 0.1354 - learning_rate: 0.0010
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.1897 - mae: 0.1565 - val_loss: 0.1714 - val_mae: 0.1272 - learning_rate: 0.0010
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1812 - mae: 0.1484 - val_loss: 0.1691 - val_mae: 0.1305 - learning_rate: 0.0010
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.1787 - mae: 0.1514 - val_loss: 0.1638 - val_mae: 0.1264 - learning_rate: 0.0010
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1789 - mae: 0.1588 - val_loss: 0.1612 - val_mae: 0.1300 - learning_rate: 0.0010
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.1685 - mae: 0.1420 - val_loss: 0.1567 - val_mae: 0.1273 - learning_rate: 0.0010
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.1657 - mae: 0.1452 - val_loss: 0.1509 - val_mae: 0.1210 - learning_rate: 0.0010
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.1595 - mae: 0.1396 - val_loss: 0.1475 - val_mae: 0.1212 - learning_rate: 0.0010
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.1556 - mae: 0.1390 - val_loss: 0.1430 - val_mae: 0.1179 - learning_rate: 0.0010
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.1504 - mae: 0.1351 - val_loss: 0.1394 - val_mae: 0.1172 - learning_rate: 0.0010
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1468 - mae: 0.1353 - val_loss: 0.1365 - val_mae: 0.1185 - learning_rate: 0.0010
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1465 - mae: 0.1409 - val_loss: 0.1335 - val_mae: 0.1192 - learning_rate: 0.0010
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1393 - mae: 0.1304 - val_loss: 0.1298 - val_mae: 0.1177 - learning_rate: 0.0010
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1362 - mae: 0.1301 - val_loss: 0.1269 - val_mae: 0.1178 - learning_rate: 0.0010
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.1342 - mae: 0.1300 - val_loss: 0.1239 - val_mae: 0.1178 - learning_rate: 0.0010
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1290 - mae: 0.1280 - val_loss: 0.1207 - val_mae: 0.1169 - learning_rate: 0.0010
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1262 - mae: 0.1291 - val_loss: 0.1173 - val_mae: 0.1151 - learning_rate: 0.0010
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1244 - mae: 0.1291 - val_loss: 0.1140 - val_mae: 0.1134 - learning_rate: 0.0010
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1203 - mae: 0.1248 - val_loss: 0.1112 - val_mae: 0.1132 - learning_rate: 0.0010
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1186 - mae: 0.1284 - val_loss: 0.1086 - val_mae: 0.1133 - learning_rate: 0.0010
# Epoch 44/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1125 - mae: 0.1205 - val_loss: 0.1058 - val_mae: 0.1123 - learning_rate: 0.0010
# Epoch 45/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1124 - mae: 0.1251 - val_loss: 0.1033 - val_mae: 0.1123 - learning_rate: 0.0010
# Epoch 46/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1080 - mae: 0.1224 - val_loss: 0.1010 - val_mae: 0.1127 - learning_rate: 0.0010
# Epoch 47/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1054 - mae: 0.1225 - val_loss: 0.0986 - val_mae: 0.1128 - learning_rate: 0.0010
# Epoch 48/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1035 - mae: 0.1226 - val_loss: 0.0963 - val_mae: 0.1126 - learning_rate: 0.0010
# Epoch 49/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.1012 - mae: 0.1230 - val_loss: 0.0940 - val_mae: 0.1123 - learning_rate: 0.0010
# Epoch 50/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0982 - mae: 0.1196 - val_loss: 0.0917 - val_mae: 0.1118 - learning_rate: 0.0010
# Epoch 51/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0966 - mae: 0.1217 - val_loss: 0.0896 - val_mae: 0.1118 - learning_rate: 0.0010
# Epoch 52/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0948 - mae: 0.1230 - val_loss: 0.0874 - val_mae: 0.1112 - learning_rate: 0.0010
# Epoch 53/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0917 - mae: 0.1192 - val_loss: 0.0853 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 54/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0902 - mae: 0.1200 - val_loss: 0.0834 - val_mae: 0.1111 - learning_rate: 0.0010
# Epoch 55/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0881 - mae: 0.1204 - val_loss: 0.0815 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 56/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0858 - mae: 0.1184 - val_loss: 0.0796 - val_mae: 0.1108 - learning_rate: 0.0010
# Epoch 57/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0832 - mae: 0.1174 - val_loss: 0.0779 - val_mae: 0.1109 - learning_rate: 0.0010
# Epoch 58/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0823 - mae: 0.1186 - val_loss: 0.0762 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 59/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0802 - mae: 0.1186 - val_loss: 0.0745 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 60/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0783 - mae: 0.1188 - val_loss: 0.0728 - val_mae: 0.1106 - learning_rate: 0.0010
# Epoch 61/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0761 - mae: 0.1165 - val_loss: 0.0712 - val_mae: 0.1104 - learning_rate: 0.0010
# Epoch 62/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0744 - mae: 0.1161 - val_loss: 0.0697 - val_mae: 0.1104 - learning_rate: 0.0010
# Epoch 63/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0736 - mae: 0.1164 - val_loss: 0.0681 - val_mae: 0.1103 - learning_rate: 0.0010
# Epoch 64/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0728 - mae: 0.1180 - val_loss: 0.0667 - val_mae: 0.1104 - learning_rate: 0.0010
# Epoch 65/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0700 - mae: 0.1160 - val_loss: 0.0653 - val_mae: 0.1103 - learning_rate: 0.0010
# Epoch 66/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0698 - mae: 0.1198 - val_loss: 0.0640 - val_mae: 0.1103 - learning_rate: 0.0010
# Epoch 67/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0679 - mae: 0.1180 - val_loss: 0.0626 - val_mae: 0.1103 - learning_rate: 0.0010
# Epoch 68/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0672 - mae: 0.1181 - val_loss: 0.0613 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 69/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0649 - mae: 0.1164 - val_loss: 0.0600 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 70/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0626 - mae: 0.1141 - val_loss: 0.0588 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 71/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0618 - mae: 0.1158 - val_loss: 0.0576 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 72/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0619 - mae: 0.1164 - val_loss: 0.0565 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 73/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0599 - mae: 0.1149 - val_loss: 0.0554 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 74/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0586 - mae: 0.1159 - val_loss: 0.0543 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 75/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0577 - mae: 0.1143 - val_loss: 0.0532 - val_mae: 0.1099 - learning_rate: 0.0010
# Epoch 76/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0570 - mae: 0.1151 - val_loss: 0.0522 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 77/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0554 - mae: 0.1134 - val_loss: 0.0512 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 78/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0546 - mae: 0.1156 - val_loss: 0.0503 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 79/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0530 - mae: 0.1137 - val_loss: 0.0494 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 80/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0531 - mae: 0.1164 - val_loss: 0.0484 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 81/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0520 - mae: 0.1150 - val_loss: 0.0476 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 82/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0512 - mae: 0.1156 - val_loss: 0.0467 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 83/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0500 - mae: 0.1146 - val_loss: 0.0459 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 84/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0493 - mae: 0.1155 - val_loss: 0.0451 - val_mae: 0.1102 - learning_rate: 0.0010
# Epoch 85/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0480 - mae: 0.1142 - val_loss: 0.0443 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 86/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0476 - mae: 0.1148 - val_loss: 0.0435 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 87/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0465 - mae: 0.1140 - val_loss: 0.0428 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 88/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0458 - mae: 0.1140 - val_loss: 0.0421 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 89/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0451 - mae: 0.1141 - val_loss: 0.0414 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 90/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0441 - mae: 0.1138 - val_loss: 0.0407 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 91/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0435 - mae: 0.1140 - val_loss: 0.0400 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 92/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0426 - mae: 0.1136 - val_loss: 0.0394 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 93/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0419 - mae: 0.1128 - val_loss: 0.0388 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 94/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0413 - mae: 0.1129 - val_loss: 0.0382 - val_mae: 0.1102 - learning_rate: 0.0010
# Epoch 95/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0411 - mae: 0.1140 - val_loss: 0.0376 - val_mae: 0.1102 - learning_rate: 0.0010
# Epoch 96/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0407 - mae: 0.1140 - val_loss: 0.0370 - val_mae: 0.1100 - learning_rate: 0.0010
# Epoch 97/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0389 - mae: 0.1123 - val_loss: 0.0365 - val_mae: 0.1101 - learning_rate: 0.0010
# Epoch 98/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0396 - mae: 0.1152 - val_loss: 0.0360 - val_mae: 0.1104 - learning_rate: 0.0010
# Epoch 99/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0387 - mae: 0.1146 - val_loss: 0.0354 - val_mae: 0.1102 - learning_rate: 0.0010
# Epoch 100/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0380 - mae: 0.1136 - val_loss: 0.0350 - val_mae: 0.1103 - learning_rate: 0.0010

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss (MSE) during Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Prediksi
y_pred_scaled = model.predict(X_test, verbose=0)

# Inverse Transform (Kembalikan ke skala Log Return asli)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_actual = scaler_y.inverse_transform(y_test)

# Rekonstruksi ke Harga Asli (Rupiah/Dollar)
# Kita butuh harga Close hari sebelumnya untuk menghitung: Harga_Esok = Harga_Hari_Ini * exp(Log_Return_Prediksi)
test_start_idx = split_idx + TIME_STEPS
base_prices = df_processed['Close'].iloc[test_start_idx-1 : -1].values

predicted_prices = base_prices * np.exp(y_pred.flatten())
actual_prices = df_processed['Close'].iloc[test_start_idx:].values[:len(predicted_prices)]

print("✅ Prediksi dan Rekonstruksi Harga Selesai")
# Out:
# ✅ Prediksi dan Rekonstruksi Harga Selesai

# %%
print("="*40)
print("📊 HASIL EVALUASI MODEL")
print("="*40)

# --- 1. Metrik Regresi (Harga) ---
rmse = np.sqrt(mean_squared_error(actual_prices, predicted_prices))
mae = mean_absolute_error(actual_prices, predicted_prices)
mape = np.mean(np.abs((actual_prices - predicted_prices) / actual_prices)) * 100

print(f"1. Error Prediksi Harga (LSTM):")
print(f"   • RMSE : {rmse:.4f}")
print(f"   • MAE  : {mae:.4f}")
print(f"   • MAPE : {mape:.2f}%")

# --- TAMBAHAN: Naive Baseline Check ---
# Strategi Naive: Tebak harga besok SAMA DENGAN harga hari ini
# Kita geser array: Prediksi hari ini adalah Harga Kemarin
y_naive_pred = actual_prices[:-1]
y_naive_true = actual_prices[1:]

naive_mape = np.mean(np.abs((y_naive_true - y_naive_pred) / y_naive_true)) * 100
naive_mae = mean_absolute_error(y_naive_true, y_naive_pred)

print(f"\n   [Benchmark] Naive Model (Besok = Hari Ini):")
print(f"   • Naive MAPE : {naive_mape:.2f}%")
print(f"   • Naive MAE  : {naive_mae:.4f}")

# Cek apakah LSTM lebih pintar dari Naive?
if mape < naive_mape:
    print(f"\n✅ KESIMPULAN: Model LSTM LEBIH PINTAR {(naive_mape - mape):.2f}% daripada tebakan asal.")
else:
    print(f"\n⚠️ KESIMPULAN: Model LSTM performanya SETARA/DI BAWAH tebakan asal (Lagging).")

# --- 2. Metrik Klasifikasi (Arah Pergerakan) ---
pred_direction = (y_pred.flatten() > 0).astype(int)
actual_direction = (y_actual.flatten() > 0).astype(int)
accuracy = accuracy_score(actual_direction, pred_direction)

print(f"\n2. Akurasi Arah Tren (Directional Accuracy):")
print(f"   • Akurasi : {accuracy*100:.2f}%")
print("\nClassification Report:")
print(classification_report(actual_direction, pred_direction, target_names=['Down', 'Up']))

# Plot Hasil
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Harga Asli', color='black', alpha=0.7)
plt.plot(predicted_prices, label='Prediksi LSTM', color='blue', alpha=0.7)
plt.title(f'Prediksi Harga Saham {TICKER} (LSTM MAPE: {mape:.2f}% vs Naive: {naive_mape:.2f}%)')
plt.xlabel('Hari ke-')
plt.ylabel('Harga')
plt.legend()
plt.show()
# Out:
# ========================================
# 📊 HASIL EVALUASI MODEL
# ========================================
# 1. Error Prediksi Harga (LSTM):
#    • RMSE : 3.3143
#    • MAE  : 2.4151
#    • MAPE : 2.35%
#
#    [Benchmark] Naive Model (Besok = Hari Ini):
#    • Naive MAPE : 2.36%
#    • Naive MAE  : 2.4297
#
# ✅ KESIMPULAN: Model LSTM LEBIH PINTAR 0.01% daripada tebakan asal.
#
# 2. Akurasi Arah Tren (Directional Accuracy):
#    • Akurasi : 55.32%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Down       0.00      0.00      0.00       126
#           Up       0.55      1.00      0.71       156
#
#     accuracy                           0.55       282
#    macro avg       0.28      0.50      0.36       282
# weighted avg       0.31      0.55      0.39       282

# %%
# Analisis Fitur mana yang paling berpengaruh
def get_feature_importance(model, X_test, y_test, features):
    baseline_mse = model.evaluate(X_test, y_test, verbose=0)[0]
    importances = []
    
    print("🔍 Menganalisis Feature Importance...")
    for i in range(len(features)):
        X_temp = X_test.copy()
        np.random.shuffle(X_temp[:, :, i]) # Acak kolom fitur ke-i
        mse = model.evaluate(X_temp, y_test, verbose=0)[0]
        # Semakin besar error naik, semakin penting fiturnya
        importances.append(mse - baseline_mse)
        
    return pd.DataFrame({'Feature': features, 'Importance': importances}).sort_values('Importance', ascending=False)

imp_df = get_feature_importance(model, X_test, y_test, feature_cols)

# Plot Feature Importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=imp_df, palette='viridis')
plt.title('Feature Importance (Kontribusi Fitur Teknikal terhadap Prediksi)')
plt.show()

print("\n💡 INTERPRETASI UNTUK SKRIPSI:")
print(f"Fitur '{imp_df.iloc[0]['Feature']}' adalah indikator paling dominan dalam model ini.")
# Out:
# 🔍 Menganalisis Feature Importance...
# 💡 INTERPRETASI UNTUK SKRIPSI:
# Fitur 'Volatility' adalah indikator paling dominan dalam model ini.

# %%
# # ==========================================
# # SAVE MODEL & COMPONENTS
# # ==========================================
# import pickle
# import os

# # Buat folder untuk simpan model
# os.makedirs('models', exist_ok=True)

# print("💾 Menyimpan model dan komponen...")

# # 1. Save Model LSTM
# model.save('models/lstm_with_indicators.keras')
# print("✅ Model saved: lstm_with_indicators.keras")

# # 2. Save Scalers
# with open('models/scaler_X_with_indicators.pkl', 'wb') as f:
#     pickle.dump(scaler_X, f)
# with open('models/scaler_y_with_indicators.pkl', 'wb') as f:
#     pickle.dump(scaler_y, f)
# print("✅ Scalers saved")

# # 3. Save Results & Metrics untuk Streamlit
# results_with_indicators = {
#     'actual_prices': actual_prices,
#     'predicted_prices': predicted_prices,
#     'rmse': rmse,
#     'mae': mae,
#     'mape': mape,
#     'naive_mape': naive_mape,
#     'accuracy': accuracy,
#     'feature_importance': imp_df.to_dict(),
#     'feature_cols': feature_cols,
#     'pred_direction': pred_direction,
#     'actual_direction': actual_direction,
#     'history': history.history,
#     'TIME_STEPS': TIME_STEPS,
#     'ticker': TICKER,
#     'split_idx': split_idx
# }

# with open('models/results_with_indicators.pkl', 'wb') as f:
#     pickle.dump(results_with_indicators, f)
# print("✅ Results saved")

# print("\n🎉 SEMUA KOMPONEN BERHASIL DISAVE!")
# print("📁 File tersimpan di folder 'models/':")
# print("   • lstm_with_indicators.keras")
# print("   • scaler_X_with_indicators.pkl")
# print("   • scaler_y_with_indicators.pkl")
# print("   • results_with_indicators.pkl")
